# %% [markdown]
# <a href="https://colab.research.google.com/github/Hirak-Pandya/Assignment-python-datacleaning/blob/main/Saathi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_excel('/content/DataSetQuestion.xlsx')
df
# Out:
#       Order ID Order Date  ...           City        Country
# 0         6374 2011-08-07  ...         Newark  United States
# 1         2209 2012-07-09  ...  New York City  United States
# 2         3808 2009-04-23  ...  San Francisco  United States
# 3            6 2012-02-20  ...  San Francisco  United States
# 4         5699 2012-07-29  ...    Los Angeles  United States
# ...        ...        ...  ...            ...            ...
# 1002        32 2008-07-15  ...  Washington DC  United States
# 1003        35 2008-10-22  ...         Newark  United States
# 1004        35 2008-10-22  ...  New York City  United States
# 1005        65 2008-10-22  ...        Seattle  United States
# 1006        36 2008-10-22  ...    Los Angeles  United States
#
# [1007 rows x 12 columns]

# %%
wrong_country=['Unite States','us','U.S.','USA']
df['Country']=df['Country'].replace(wrong,'United States',regex=True)

# %% [markdown]
# https://www.geeksforgeeks.org/replace-values-in-pandas-dataframe-using-regex/

# %%
df.head(30)
# Out:
#     Order ID Order Date  ...           City         Country
# 0       6374 2011-08-07  ...         Newark   United States
# 1       2209 2012-07-09  ...  New York City   United States
# 2       3808 2009-04-23  ...  San Francisco   United States
# 3          6 2012-02-20  ...  San Francisco   United States
# 4       5699 2012-07-29  ...    Los Angeles   United States
# 5       4835 2009-10-24  ...  San Francisco   United States
# 6       4738 2012-04-07  ...         Newark   United States
# 7       3073 2009-01-07  ...  San Francisco   United States
# 8       7043 2009-01-25  ...  New York City   United States
# 9       6788 2011-08-04  ...  San Francisco   United States
# 10      1985 2009-09-01  ...  Staten Island   United States
# 11      2305 2010-01-25  ...      Cambridge   United States
# 12      5061 2010-08-13  ...             SF   United States
# 13      3395 2009-10-29  ...      St. Louis   United States
# 14      1221 2012-04-18  ...  San Francisco   United States
# ...

# %%
wrong_city1=['New york','new york','New York City']
d = [r'\b' + k + r'\b' for k in wrong_city1]
wrong_city2=['SF','San Franciscocisco','San Francisco','san francisco'	]
df['City']=df['City'].replace(d,'NYC',regex=True)
df['City']=df['City'].replace(wrong_city2,'San Fran',regex=True)
df['City']=df['City'].replace('LA','Los Angeles',regex=True)
df['City']=df['City'].replace('seatle','Seattle',regex=True)
df['City']=df['City'].replace('Vancover','Vancouver',regex=True)

# %%
df['City']=df['City'].replace('NYC city','NYC')

# %%
df.head(50)
# Out:
#     Order ID Order Date  ...           City         Country
# 0       6374 2011-08-07  ...         Newark   United States
# 1       2209 2012-07-09  ...            NYC   United States
# 2       3808 2009-04-23  ...       San Fran   United States
# 3          6 2012-02-20  ...       San Fran   United States
# 4       5699 2012-07-29  ...    Los Angeles   United States
# 5       4835 2009-10-24  ...       San Fran   United States
# 6       4738 2012-04-07  ...         Newark   United States
# 7       3073 2009-01-07  ...       San Fran   United States
# 8       7043 2009-01-25  ...            NYC   United States
# 9       6788 2011-08-04  ...       San Fran   United States
# 10      1985 2009-09-01  ...  Staten Island   United States
# 11      2305 2010-01-25  ...      Cambridge   United States
# 12      5061 2010-08-13  ...       San Fran   United States
# 13      3395 2009-10-29  ...      St. Louis   United States
# 14      1221 2012-04-18  ...       San Fran   United States
# ...

# %%
df.to_excel('Clean datasheet.xlsx')
